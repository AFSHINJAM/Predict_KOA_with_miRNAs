# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from varclushi import VarClusHi
# %matplotlib inline

df = pd.read_excel (r"C:\Users\afshi\OneDrive - McGill University\New folder\DATA1.xlsx")
df.head(3)

df = df.iloc[:, 5:466]

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform the data
df_scaled = scaler.fit_transform(df)

# Convert the resulting numpy array back to a pandas dataframe
df_scaled = pd.DataFrame(df_scaled, columns=df.columns)
df_scaled.head(3)
# Out:
#    hsa-let-7a-3p  hsa-let-7a-5p  hsa-let-7b-3p  hsa-let-7b-5p  hsa-let-7c-5p  \
# 0      -0.623167      -0.299742      -0.633988      -0.975306      -0.311270
# 1      -0.623167      -0.064839      -0.114062      -0.313393      -0.268718
# 2      -0.623167      -0.719790      -0.690042       0.330482      -0.319568
#
#    hsa-let-7d-3p  hsa-let-7d-5p  hsa-let-7e-5p  hsa-let-7f-1-3p  \
# 0      -0.428355       0.333339      -0.609761         1.070133
# 1      -0.580313      -0.286349      -0.629469         0.633728
# 2       0.758829      -0.700654      -0.399155        -0.663374
#
#    hsa-let-7f-5p  ...  hsa-miR-940  hsa-miR-941  hsa-miR-942-5p  \
# 0       0.926103  ...    -0.532044     0.728898       -1.714285
# 1      -0.117130  ...     0.343259    -0.155438       -0.934895
# 2      -0.613866  ...    -0.532044    -0.127582       -0.551620
#
#    hsa-miR-95-3p  hsa-miR-96-5p  hsa-miR-98-5p  hsa-miR-99a-3p  \
# 0      -0.111001      -0.930787      -0.364464       -0.309561
# 1      -0.501546       1.424402       0.484961       -0.309561
# 2       0.170149      -0.531130      -0.805898       -0.132428
#
#    hsa-miR-99a-5p  hsa-miR-99b-3p  hsa-miR-99b-5p
# 0       -0.517764        0.063519       -0.296862
# 1       -0.305721        0.424517       -0.614241
# 2       -0.548406        0.161551        0.326155
#
# [3 rows x 461 columns]

# %%
Var_clus_model = VarClusHi(df_scaled, maxeigval2 = 0.7, maxclus= None)
Var_clus_model.varclus()
pd.options.display.max_rows = len(Var_clus_model.rsquare)
print(Var_clus_model.rsquare)

# %%
df2 = pd.DataFrame(Var_clus_model.rsquare)

# group the data by the "Cluster" column
grouped = df2.groupby("Cluster")

# select the index of the minimum "RS_Ratio" for each group
min_idx = grouped["RS_Ratio"].idxmin()

# extract the corresponding "Variable" values
selected_vars = df2.loc[min_idx, "Variable"]

df3 = df[selected_vars]

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform the data
df_scaled = scaler.fit_transform(df3)

# Convert the resulting numpy array back to a pandas dataframe
df_scaled = pd.DataFrame(df_scaled, columns=df3.columns)

# %%
Var_clus_model = VarClusHi(df_scaled, maxeigval2 = 0.7, maxclus= None)
Var_clus_model.varclus()
pd.options.display.max_rows = len(Var_clus_model.rsquare)

# %%
df4 = pd.DataFrame(Var_clus_model.rsquare)

# group the data by the "Cluster" column
grouped = df4.groupby("Cluster")

# select the index of the minimum "RS_Ratio" for each group
min_idx = grouped["RS_Ratio"].idxmin()

# extract the corresponding "Variable" values
selected_vars = df4.loc[min_idx, "Variable"]

df5 = df[selected_vars]

# %%
# Initialize StandardScaler
scaler = StandardScaler()

# Fit and transform the data
df_scaled = scaler.fit_transform(df5)

# Convert the resulting numpy array back to a pandas dataframe
df_scaled = pd.DataFrame(df_scaled, columns=df5.columns)
df_scaled.head(3)

# %%
from varclushi import VarClusHi
Var_clus_model = VarClusHi(df_scaled, maxeigval2 = 0.7, maxclus= None)
Var_clus_model.varclus()
pd.options.display.max_rows = len(Var_clus_model.rsquare)

# %%
import pandas as pd
from varclushi import VarClusHi

# Assuming df_scaled is your DataFrame
Var_clus_model = VarClusHi(df_scaled, maxeigval2=0.7, maxclus=None)
Var_clus_model.varclus()

# Update DataFrame formatting options
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.float_format = '{:.3f}'.format  # Set to 3 decimal places
pd.options.display.max_colwidth = None  # Set column width to None (unlimited)

# Print the DataFrame
print(Var_clus_model.rsquare)

# Round the decimals and save the DataFrame to an Excel file
Var_clus_model.rsquare.round(3).to_excel("varclus_results.xlsx", index=False)
